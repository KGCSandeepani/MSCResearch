# %% [markdown]
# # Metrics
#
# ## Method Metric
#
# | Index | Metric name |
# | --- | --- |
# | C1 | Lines of Code |
# | C2 | Number of Comment lines |
# | C3 | Number of all lines |
# | C4 | Number of Blank lines |
# | C5 | Number of Declare lines |
# | C6 | Number of Executable lines |
# | C7 | Number of Parameters |
# | C8 | Number of Statements |
# | C9 | Number of Declare Statements |
# | C10 | Number of Executable Statements |
# | C11 | Halstead-Vocabulary |
# | C12 | Halstead-Length |
# | C13 | Halstead-Difficulty |
# | C14 | Halstead-Volume |
# | C15 | Halstead-Effort |
# | C16 | Halstead-Bugs |
# | C17 | Cyclomatic complexity |
# | C18 | Number of Path |
# | C19 | MaxNesting |
# | C20 | Fan-in |
# | C21 | Fan-out |
#
#
# ## History Metric
#
# | Index | Metric name |
# | --- | --- |
# | H1 | Added LOC |
# | H2 | Deleted LOC |
# | H3 | Changed LOC |
# | H4 | Number of Changes |
# | H5 | Number of Authors |
# | H6 | Number of Modified Statements |
# | H7 | Number of Modified Expressions |
# | H8 | Number of Modified Comments |
# | H9 | Number of Modified Return type |
# | H10 | Number of Modified Parameters |
# | H11 | Number of Modified Prefix |
# | H12 | Added LOC/LOC |
# | H13 | Deleted LOC/LOC |
# | H14 | Added LOC/Deleted LOC |
# | H15 | Changed LOC/Number of Changes |
# | H16 | Number of Modified Statements/ Number of Statements |
# | H17 | Number of Modified Expressions/ Number of Statements |
# | H18 | Number of Modified Comments/ LOC |
# | H19 | Number of Modified Parameters/ Number of Parameters |

# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore', category = FutureWarning)

# %%
# Import pandas libraries
import pandas as pd

# Load the dataset
data = pd.read_csv("Data/activemq_result.csv", delimiter=',')

# Explore the dataset
print(data.head()) # print first few rows
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
#                                          Method name  C20  C3  C4  C1  C5  C6  \
# 0  org.apache.activemq.transport.amqp.AmqpFramePa...    4  10   1   9   2   5
# 1  org.apache.activemq.transport.amqp.AmqpHeader....    5   6   0   6   1   3
# 2  org.apache.activemq.transport.amqp.AmqpHeader....    1  13   0  13   3   9
# 3  org.apache.activemq.transport.amqp.AmqpInactiv...    1   5   0   5   1   3
# 4  org.apache.activemq.transport.amqp.AmqpInactiv...    6   9   0   9   1   5
#
#    C2  C21  C18  ...  H4  H1  H2  H3       H12       H13       H14   H15  H5  \
# 0   0    2    4  ...   1   2   2   4  0.200000  0.200000  1.000000   4.0   1
# 1   0    5    2  ...   1   1   3   4  0.333333  1.000000  0.333333   4.0   1
# ...

# %% [markdown]
# # Preprocessing

# %%
# Explore the dataset information
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4016 entries, 0 to 4015
# Data columns (total 42 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Method name  4016 non-null   object
#  1   C20          4016 non-null   int64
#  2   C3           4016 non-null   int64
#  3   C4           4016 non-null   int64
#  4   C1           4016 non-null   int64
#  5   C5           4016 non-null   int64
#  6   C6           4016 non-null   int64
#  7   C2           4016 non-null   int64
#  8   C21          4016 non-null   int64
#  9   C18          4016 non-null   int64
#  10  C8           4016 non-null   int64
#  11  C9           4016 non-null   int64
#  12  C10          4016 non-null   int64
#  13  C17          4016 non-null   int64
#  14  C19          4016 non-null   int64
#  15  C7           4016 non-null   int64
#  16  C11          4016 non-null   float64
#  17  C12          4016 non-null   float64
# ...

# %%
# Handle missing values:# get missing value count of each column

# Replace missing values with NaN
# data.replace('?', pd.NA, inplace=True)

# Check missing value
data.isna().sum()
# Out:
# Method name    0
# C20            0
# C3             0
# C4             0
# C1             0
# C5             0
# C6             0
# C2             0
# C21            0
# C18            0
# C8             0
# C9             0
# C10            0
# C17            0
# C19            0
# C7             0
# C11            0
# C12            0
# C13            0
# C14            0
# C15            0
# C16            0
# H6             0
# H7             0
# H8             0
# H9             0
# H10            0
# H11            0
# H16            0
# H17            0
# H18            0
# H19            0
# H4             0
# H1             0
# H2             0
# H3             0
# H12            0
# H13            0
# H14            0
# H15            0
# H5             0
# bug-prone      0
# dtype: int64

# %%
# check missing values
data.isnull().values.any() # no missing values
# Out:
# False

# %%
import numpy as np

data.replace([np.inf, -np.inf], np.nan, inplace=True)

# Check missing value
data.isna().sum() # get missing value count of each column
# Out:
# Method name    0
# C20            0
# C3             0
# C4             0
# C1             0
# C5             0
# C6             0
# C2             0
# C21            0
# C18            0
# C8             0
# C9             0
# C10            0
# C17            0
# C19            0
# C7             0
# C11            0
# C12            0
# C13            0
# C14            0
# C15            0
# C16            0
# H6             0
# H7             0
# H8             0
# H9             0
# H10            0
# H11            0
# H16            0
# H17            0
# H18            0
# H19            0
# H4             0
# H1             0
# H2             0
# H3             0
# H12            0
# H13            0
# H14            0
# H15            0
# H5             0
# bug-prone      0
# dtype: int64

# %%
# # fill NaN values with a specific value (e.g., mean or median)
# data.fillna(data.mean(), inplace=True)

# %%
# Explore dataset
data.describe()
# Out:
#                C20           C3           C4           C1           C5  \
# count  4016.000000  4016.000000  4016.000000  4016.000000  4016.000000
# mean      6.653137    16.582669     1.035857    13.347859     2.329930
# std      19.184974    19.970829     2.504633    16.064588     2.431008
# min       0.000000     1.000000     0.000000     1.000000     1.000000
# 25%       2.000000     6.000000     0.000000     3.000000     1.000000
# 50%       4.000000    10.000000     0.000000     8.000000     1.000000
# 75%       7.000000    20.000000     1.000000    16.000000     3.000000
# max     840.000000   256.000000    28.000000   235.000000    33.000000
#
#                 C6           C2          C21           C18           C8  ...  \
# count  4016.000000  4016.000000  4016.000000  4.016000e+03  4016.000000  ...
# mean      9.214392     2.222112     6.671315  2.765350e+05     9.532371  ...
# std      12.828308     4.165023     7.411817  1.583541e+07    11.853798  ...
# ...

# %%
# Check the outliers

import matplotlib.pyplot as plt

# Increase the size of the plot
plt.figure(figsize=(12, 10))  # width-12 and height-10

# Create the boxplot
data.boxplot()

# Rotate the tick labels on the y-axis
plt.xticks(rotation=90)

# Show the plot
plt.show()

# Dataset has outliers. They will be handled by appling transformation.

# %%
# For each column draw the boxplot
columns = data.columns

# Adjust the size of the plot
plt.figure(figsize=(5, 10))

# Check any outliers in the dataset under each feature 
temp_df = pd.DataFrame(data, columns=[columns[4]])    
temp_df.boxplot()

plt.show()

# %%
data.columns
# Out:
# Index(['Method name', 'C20', 'C3', 'C4', 'C1', 'C5', 'C6', 'C2', 'C21', 'C18',
#        'C8', 'C9', 'C10', 'C17', 'C19', 'C7', 'C11', 'C12', 'C13', 'C14',
#        'C15', 'C16', 'H6', 'H7', 'H8', 'H9', 'H10', 'H11', 'H16', 'H17', 'H18',
#        'H19', 'H4', 'H1', 'H2', 'H3', 'H12', 'H13', 'H14', 'H15', 'H5',
#        'bug-prone'],
#       dtype='object')

# %%
# # Import neccessary libraries
# import numpy as np
# import scipy.stats as stats
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Set the style of seaborn
# sns.set(style="whitegrid")

# # Define a function to plot histograms and Q-Q plots
# def plot_distribution(feature):
#     # Create a figure with two subplots
#     fig, axes = plt.subplots(1, 2, figsize=(8, 4))
    
#     # Plot histogram
#     sns.histplot(data[feature], ax=axes[0], kde=True)
#     axes[0].set_title('Histogram of {}'.format(feature))
    
#     # Plot Q-Q plot
#     stats.probplot(data[feature], dist="norm", plot=axes[1])
#     axes[1].set_title('Q-Q plot of {}'.format(feature))
    
#     # Adjust layout
#     plt.tight_layout()
#     plt.show()

# # remove categorical columns
# # df = data.drop(columns = ['Method name','bug-prone'])

# # Select numerical columns only
# df = data.select_dtypes(include=['number']).apply(pd.to_numeric, downcast='float')

# # Iterate over each numerical column and plot distributions
# for column in df.columns:
#     plot_distribution(column)
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\anaconda3\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df = data.select_dtypes(include=['number']).apply(pd.to_numeric, downcast='float')
df.columns
# Out:
# Index(['C20', 'C3', 'C4', 'C1', 'C5', 'C6', 'C2', 'C21', 'C18', 'C8', 'C9',
#        'C10', 'C17', 'C19', 'C7', 'C11', 'C12', 'C13', 'C14', 'C15', 'C16',
#        'H6', 'H7', 'H8', 'H9', 'H10', 'H11', 'H16', 'H17', 'H18', 'H19', 'H4',
#        'H1', 'H2', 'H3', 'H12', 'H13', 'H14', 'H15', 'H5'],
#       dtype='object')

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

def plot_dist(feature):
    # Create a figure
    plt.figure(figsize=(6, 4))
    
    # Plot histogram and KDE
    sns.histplot(data[feature], kde=True, stat="density", bins=30, color='blue', alpha=0.6)
    sns.kdeplot(data[feature], color='red', linewidth=2)
    plt.title(f'Distribution of {feature}')
    
    # Show the plot
    plt.tight_layout()
    plt.show()

# # Define a function to plot distributions
# def plot_dist(feature):
#     # Create a figure
#     plt.figure(figsize=(6, 4))
    
#     # Plot distribution
#     sns.distplot(data[feature], kde=True, hist=True, rug=True)
#     plt.title(f'Distribution of {feature}')
    
#     # Show the plot
#     plt.tight_layout()
#     plt.show()

# Select numerical columns only
df = data.select_dtypes(include=['number']).apply(pd.to_numeric, downcast='float')

# Iterate over each numerical column and plot distributions
for column in df.columns:
    plot_dist(column)

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Set the style of seaborn
sns.set(style="whitegrid")

def plot_all_distributions(df):
    # Number of columns in the dataframe
    num_features = df.shape[1]
    
    # Calculate the number of rows and columns for subplots
#     num_cols = 5  # Number of columns in the grid
#     num_rows = (num_features + num_cols - 1) // num_cols  # Compute rows dynamically
    
    # Create a figure with subplots
    fig, axes = plt.subplots(8, 5, figsize=(15, 24))
    
    # Flatten axes array for easy iteration
    axes = axes.flatten()
    
    # Plot each feature
    for i, column in enumerate(df.columns):
        sns.histplot(df[column], kde=True, stat="density", bins=30, color='blue', alpha=0.6, ax=axes[i])
        sns.kdeplot(df[column], color='red', linewidth=2, ax=axes[i])
        axes[i].set_title(f'Distribution of {column}')
    
    # Hide any unused subplots
    for i in range(len(df.columns), len(axes)):
        axes[i].axis('off')
    
    # Adjust layout
    plt.tight_layout()
    plt.show()

# Select numerical columns only
df = data.select_dtypes(include=['number']).apply(pd.to_numeric, downcast='float')

# Plot all distributions
plot_all_distributions(df)

# %%
# # Apply a logarithmic transformation to the variables with right-skewed distributions since it mostly suitable when the 
# # distribution is right-skewed.

# # Import numpy
# import numpy as np

# copy data_cleaned data to data_transform
data_transform = data.copy()

# # Apply logarithmic transformation to each variable
# # Using np.log1p to avoid issues with zero values
# for var in df.columns:
#     data_transform[var] = np.log1p(data_transform[var]) 

# # Check the distribution after transformation
# data_transform[df.columns].hist(figsize=(20, 20))



# Apply a Box-Cox transformation to the variables with right-skewed distributions since following columns are not transform
# to symmetrical distribution by using logarithmic transformation.

# Import scipy
from scipy import stats

# Apply Box-Cox transformation to each variable
for var in df.columns:
    # Adding 1 to handle zero values
    transformed, _ = stats.boxcox(data_transform[var] + 1)
    data_transform[var] = transformed

# Check the distribution after transformation
data_transform[df.columns].hist(figsize=(20, 20))
# Out:
# array([[<Axes: title={'center': 'C20'}>, <Axes: title={'center': 'C3'}>,
#         <Axes: title={'center': 'C4'}>, <Axes: title={'center': 'C1'}>,
#         <Axes: title={'center': 'C5'}>, <Axes: title={'center': 'C6'}>],
#        [<Axes: title={'center': 'C2'}>, <Axes: title={'center': 'C21'}>,
#         <Axes: title={'center': 'C18'}>, <Axes: title={'center': 'C8'}>,
#         <Axes: title={'center': 'C9'}>, <Axes: title={'center': 'C10'}>],
#        [<Axes: title={'center': 'C17'}>, <Axes: title={'center': 'C19'}>,
#         <Axes: title={'center': 'C7'}>, <Axes: title={'center': 'C11'}>,
#         <Axes: title={'center': 'C12'}>, <Axes: title={'center': 'C13'}>],
#        [<Axes: title={'center': 'C14'}>, <Axes: title={'center': 'C15'}>,
#         <Axes: title={'center': 'C16'}>, <Axes: title={'center': 'H6'}>,
#         <Axes: title={'center': 'H7'}>, <Axes: title={'center': 'H8'}>],
#        [<Axes: title={'center': 'H9'}>, <Axes: title={'center': 'H10'}>,
# ...

# %%
data_transform.columns
# Out:
# Index(['Method name', 'C20', 'C3', 'C4', 'C1', 'C5', 'C6', 'C2', 'C21', 'C18',
#        'C8', 'C9', 'C10', 'C17', 'C19', 'C7', 'C11', 'C12', 'C13', 'C14',
#        'C15', 'C16', 'H6', 'H7', 'H8', 'H9', 'H10', 'H11', 'H16', 'H17', 'H18',
#        'H19', 'H4', 'H1', 'H2', 'H3', 'H12', 'H13', 'H14', 'H15', 'H5',
#        'bug-prone'],
#       dtype='object')

# %%
# Convert 'bug-prone' column to 0 and 1
data_transform['bug-prone'] = data_transform['bug-prone'].apply(lambda x: 1 if x.strip() == 'bug-prone' else 0)

print(data_transform.head())
# Out:
#                                          Method name       C20        C3  \
# 0  org.apache.activemq.transport.amqp.AmqpFramePa...  1.375132  1.785511
# 1  org.apache.activemq.transport.amqp.AmqpHeader....  1.504691  1.528033
# 2  org.apache.activemq.transport.amqp.AmqpHeader....  0.647044  1.911030
# 3  org.apache.activemq.transport.amqp.AmqpInactiv...  0.647044  1.433087
# 4  org.apache.activemq.transport.amqp.AmqpInactiv...  1.610589  1.733699
#
#         C4        C1        C5        C6   C2       C21       C18  ...  \
# 0  0.37098  1.540882  0.529868  1.491733  0.0  0.967155  0.854736  ...
# 1  0.00000  1.380233  0.426113  1.201780  0.0  1.459723  0.700577  ...
# 2  0.00000  1.673912  0.572701  1.823398  0.0  1.774272  0.795908  ...
# 3  0.00000  1.303854  0.426113  1.201780  0.0  1.181458  0.517100  ...
# 4  0.00000  1.540882  0.426113  1.491733  0.0  1.337903  0.795908  ...
#
#          H4        H1        H2        H3       H12       H13       H14  \
# ...

# %%
# Import libraries
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

# split feature data and target data
feature_X = data_transform.drop(columns=['Method name','bug-prone'])
y = data_transform['bug-prone']

# Z-score standardization
scaler_standard = StandardScaler()
scaled_data = scaler_standard.fit_transform(feature_X)
scaled_data_df = pd.DataFrame(scaled_data, columns=feature_X.columns)

# StandardScaler is used because the relative relationships between data points are preserved and less sensitive to the 
# presence of outliers compared to other scaling methods like Min-Max scaling.

# %%
# Explore dataset
scaled_data_df.describe()
# Out:
#                 C20            C3            C4            C1            C5  \
# count  4.016000e+03  4.016000e+03  4.016000e+03  4.016000e+03  4.016000e+03
# mean  -3.715487e-16  5.520153e-16  1.840051e-16  4.670898e-16  2.547763e-16
# std    1.000125e+00  1.000125e+00  1.000125e+00  1.000125e+00  1.000125e+00
# min   -2.504425e+00 -2.684276e+00 -6.382415e-01 -2.700061e+00 -9.159263e-01
# 25%   -6.742914e-01 -5.953575e-01 -6.382415e-01 -1.253728e+00 -9.159263e-01
# 50%    4.847809e-02  6.521644e-03 -6.382415e-01  2.309507e-02 -9.159263e-01
# 75%    6.510448e-01  7.537064e-01  1.217759e+00  7.849411e-01  1.027000e+00
# max    4.347463e+00  2.708662e+00  1.811428e+00  2.556681e+00  2.008119e+00
#
#                  C6            C2           C21           C18            C8  \
# count  4.016000e+03  4.016000e+03  4.016000e+03  4.016000e+03  4.016000e+03
# mean   2.123136e-16  6.369407e-17  5.166297e-16 -2.193907e-16  4.529356e-16
# ...

# %%
# independent

# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# Compute the correlation matrix
corr_matrix = scaled_data_df.corr()

# Plot a heatmap of the correlation matrix
plt.figure(figsize=(25, 25))
sns.heatmap(corr_matrix, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Calculate feature importances
from sklearn.ensemble import RandomForestRegressor

# Create a random forest regressor model
rf = RandomForestRegressor()

# Fit the model to scaled data
rf.fit(scaled_data_df, y)

# Extract feature importances
feature_importances = rf.feature_importances_

# Plot feature importances
plt.figure(figsize=(20, 6))
plt.bar(range(len(feature_importances)), feature_importances, tick_label=scaled_data_df.columns)
plt.title('Feature Importances')
plt.xlabel('Features')
plt.ylabel('Importance Score')
plt.xticks(rotation=90)
plt.show()

# This plot is shows the feature importances using a Random Forest Regressor model

# %% [markdown]
# # Full dataset test using individual algorithm

# %%
# Import train_test_split library
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and testing sets (20%)
X_train, X_test, y_train, y_test = train_test_split(scaled_data_df, y, test_size=0.2, random_state=42)

# %%
# Random Forest 

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, roc_auc_score, roc_curve

# Initialize and train the Random Forest classifier
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train, y_train)

# Make predictions on the test set
rf_pred = rf_classifier.predict(X_test)
rf_probs = rf_classifier.predict_proba(X_test)[:, 1]  # Probabilities for the positive class

# Evaluate performance
accuracy = accuracy_score(y_test, rf_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, rf_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, rf_pred))

# AUC score
auc = roc_auc_score(y_test, rf_probs)
print("\nAUC:", auc)

# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, rf_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# Accuracy: 0.7935323383084577
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.83      0.83       487
#            1       0.74      0.74      0.74       317
#
#     accuracy                           0.79       804
#    macro avg       0.78      0.78      0.78       804
# weighted avg       0.79      0.79      0.79       804
#
#
# Confusion Matrix:
# [[404  83]
#  [ 83 234]]
#
# AUC: 0.879488142817352

# %%
# Gradient Boosting classifier

# Gradient Boosting classifiers are powerful ensemble methods that can capture complex patterns and interactions in the data. They perform well in a wide range of datasets and are robust to overfitting. Gradient Boosting is suitable for datasets where accuracy is a priority and interpretability is less critical.

from sklearn.ensemble import GradientBoostingClassifier

# Initialize and train the Gradient Boosting classifier
gb_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)
gb_classifier.fit(X_train, y_train)

# Make predictions on the test set
gb_pred = gb_classifier.predict(X_test)
gb_probs = gb_classifier.predict_proba(X_test)[:, 1]

# Evaluate performance
accuracy = accuracy_score(y_test, gb_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, gb_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, gb_pred))

# AUC score
auc = roc_auc_score(y_test, gb_probs)
print("\nAUC:", auc)

# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, gb_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# Accuracy: 0.753731343283582
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.84      0.81       487
#            1       0.72      0.62      0.66       317
#
#     accuracy                           0.75       804
#    macro avg       0.75      0.73      0.73       804
# weighted avg       0.75      0.75      0.75       804
#
#
# Confusion Matrix:
# [[410  77]
#  [121 196]]
#
# AUC: 0.837600969043717

# %%
# SVC

# I choose SVC becouse selected dataset has 60 features after feature selection. SVCs are effective for high-dimensional datasets and are versatile in handling both linear and non-linear decision boundaries. They can capture complex relationships between features and target variables, making them suitable for datasets with intricate patterns.

from sklearn.svm import SVC

# Initialize and train the SVC classifier
svm_classifier = SVC(kernel='linear', probability=True, random_state=42)
svm_classifier.fit(X_train, y_train)

# Make predictions on the test set
svm_pred = svm_classifier.predict(X_test)
svm_probs = svm_classifier.predict_proba(X_test)[:, 1]

# Evaluate performance
accuracy = accuracy_score(y_test, svm_pred)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, svm_pred))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, svm_pred))

# AUC score
auc = roc_auc_score(y_test, svm_probs)
print("\nAUC:", auc)

# Plot ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, svm_probs)
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f"ROC Curve (AUC = {auc:.2f})")
plt.plot([0, 1], [0, 1], "k--", label="Random Guess")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("Receiver Operating Characteristic (ROC) Curve")
plt.legend(loc="lower right")
plt.grid()
plt.show()
# Out:
# Accuracy: 0.7276119402985075
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.82      0.79       487
#            1       0.68      0.58      0.63       317
#
#     accuracy                           0.73       804
#    macro avg       0.72      0.70      0.71       804
# weighted avg       0.72      0.73      0.72       804
#
#
# Confusion Matrix:
# [[400  87]
#  [132 185]]
#
# AUC: 0.8124680170230407

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# Initialize and train the Bagging classifier
bagging_classifier = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging_classifier.fit(X_train, y_train)

# Predictions
bagging_pred = bagging_classifier.predict(X_test)
bagging_probs = bagging_classifier.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, bagging_pred)
print("Accuracy:", accuracy)

print("\nClassification Report:")
print(classification_report(y_test, bagging_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, bagging_pred))

# AUC score
auc = roc_auc_score(y_test, bagging_probs)
print("\nAUC:", auc)
# Out:
# Accuracy: 0.7885572139303483
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       487
#            1       0.74      0.72      0.73       317
#
#     accuracy                           0.79       804
#    macro avg       0.78      0.78      0.78       804
# weighted avg       0.79      0.79      0.79       804
#
#
# Confusion Matrix:
# [[407  80]
#  [ 90 227]]
#
# AUC: 0.8696195726102642

# %%
from xgboost import XGBClassifier

# Define the XGBoost classifier
xgb_model = XGBClassifier(
    objective='binary:logistic',  # Binary classification
    eval_metric='logloss',       # Loss metric for evaluation
#     use_label_encoder=False,     # Disable encoding of labels
    n_estimators=100,            # Number of trees
    max_depth=6,                 # Maximum tree depth
    learning_rate=0.1,           # Learning rate
    random_state=42              # For reproducibility
)

xgb_model.fit(X_train, y_train)

# Predictions
xgb_pred = xgb_model.predict(X_test)
xgb_probs = xgb_model.predict_proba(X_test)[:, 1]

accuracy = accuracy_score(y_test, xgb_pred)
print("Accuracy:", accuracy)

print("\nClassification Report:")
print(classification_report(y_test, xgb_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, xgb_pred))

# AUC score
auc = roc_auc_score(y_test, xgb_probs)
print("\nAUC:", auc)
# Out:
# Accuracy: 0.7748756218905473
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.83      0.82       487
#            1       0.73      0.68      0.71       317
#
#     accuracy                           0.77       804
#    macro avg       0.77      0.76      0.76       804
# weighted avg       0.77      0.77      0.77       804
#
#
# Confusion Matrix:
# [[406  81]
#  [100 217]]
#
# AUC: 0.8550839168539763

# %% [markdown]
# ## Get final output applying combine rule

# %%
# Average Probabilities

avg_probs = (rf_probs + gb_probs + svm_probs) / 3

final_preds = (avg_probs >= 0.5).astype(int)

# Evaluate performance
accuracy = accuracy_score(y_test, final_preds)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, final_preds))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, final_preds))
# Out:
# Accuracy: 0.7661691542288557
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.85      0.82       487
#            1       0.74      0.63      0.68       317
#
#     accuracy                           0.77       804
#    macro avg       0.76      0.74      0.75       804
# weighted avg       0.76      0.77      0.76       804
#
#
# Confusion Matrix:
# [[415  72]
#  [116 201]]

# %%
# Average Probabilities with optimal threshold

# avg_probs = (rf_probs + bagging_probs + xgb_probs) / 3

# final_preds = (avg_probs >= 0.5).astype(int)

# # Evaluate performance
# accuracy = accuracy_score(y_test, final_preds)
# print("Accuracy:", accuracy)

# # Classification report
# print("\nClassification Report:")
# print(classification_report(y_test, final_preds))

# # Confusion matrix
# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, final_preds))

# Accuracy: 0.7922885572139303

# Classification Report:
#               precision    recall  f1-score   support

#            0       0.83      0.83      0.83       487
#            1       0.74      0.73      0.73       317

#     accuracy                           0.79       804
#    macro avg       0.78      0.78      0.78       804
# weighted avg       0.79      0.79      0.79       804


# Confusion Matrix:
# [[406  81]
#  [ 86 231]]



from sklearn.metrics import (
    roc_curve, roc_auc_score, accuracy_score, precision_score,
    recall_score, f1_score, matthews_corrcoef
)

import numpy as np


# Assuming rf_probs, bagging_probs, and xgb_probs are predicted probabilities
avg_probs = (rf_probs + bagging_probs + xgb_probs) / 3 

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, avg_probs)

# Compute Youden's Index
youden_index = tpr - fpr
optimal_idx = np.argmax(youden_index)
optimal_threshold = thresholds[optimal_idx]

# Print optimal threshold
print(f"Optimal Threshold (Youden's Index): {optimal_threshold:.4f}")

# Apply the optimal threshold
final_preds = (avg_probs >= optimal_threshold).astype(int)

# Evaluate combined results
print("\nFinal Combined Results (Using Optimal Threshold):")
print(f"Accuracy: {accuracy_score(y_test, final_preds):.4f}")
print(f"Precision: {precision_score(y_test, final_preds):.4f}")
print(f"Recall: {recall_score(y_test, final_preds):.4f}")
print(f"F1-Score: {f1_score(y_test, final_preds):.4f}")
print(f"MCC: {matthews_corrcoef(y_test, final_preds):.4f}")
print(f"AUC: {roc_auc_score(y_test, avg_probs):.4f}")

# Optimal Threshold using Youden's Index: 0.4081

# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7836
# Precision: 0.6857
# Recall: 0.8328
# F1-Score: 0.7521
# MCC: 0.5716
# AUC: 0.8689
# Out:
# Optimal Threshold (Youden's Index): 0.4850
#
# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7960
# Precision: 0.7311
# Recall: 0.7634
# F1-Score: 0.7469
# MCC: 0.5766
# AUC: 0.8771

# %%
# majority voting

# Get predicted classes (binary outputs: 0 or 1)
# rf_preds = rf_classifier.predict(X_test)
# gb_preds = gb_classifier.predict(X_test)
# svm_preds = svm_classifier.predict(X_test)

# Combine predictions using majority voting
import numpy as np
# votes = np.array([rf_preds, gb_preds, svm_preds])
votes = np.array([rf_pred, bagging_pred, xgb_pred])
final_preds = np.apply_along_axis(lambda x: np.bincount(x).argmax(), axis=0, arr=votes)


# Evaluate performance
accuracy = accuracy_score(y_test, final_preds)
print("Accuracy:", accuracy)

# Classification report
print("\nClassification Report:")
print(classification_report(y_test, final_preds))

# Confusion matrix
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, final_preds))

# Evaluate combined results
print(f"Accuracy: {accuracy_score(y_test, final_preds):.4f}")
print(f"Precision: {precision_score(y_test, final_preds):.4f}")
print(f"Recall: {recall_score(y_test, final_preds):.4f}")
print(f"F1-Score: {f1_score(y_test, final_preds):.4f}")
print(f"MCC: {matthews_corrcoef(y_test, final_preds):.4f}")
# Out:
# Accuracy: 0.7922885572139303
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.84      0.83       487
#            1       0.74      0.72      0.73       317
#
#     accuracy                           0.79       804
#    macro avg       0.78      0.78      0.78       804
# weighted avg       0.79      0.79      0.79       804
#
#
# Confusion Matrix:
# [[408  79]
#  [ 88 229]]
# Accuracy: 0.7923
# Precision: 0.7435
# Recall: 0.7224
# F1-Score: 0.7328
# MCC: 0.5631

# %% [markdown]
# # Train 4 models based on LOC

# %%
# Import train_test_split library
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and testing sets (20%)
X_train, X_test, y_train, y_test = train_test_split(scaled_data_df, y, test_size=0.2, random_state=42)

# %%
import numpy as np
import pandas as pd

# Calculate percentiles
c1_25 = np.percentile(X_train['C1'], 25)
c1_50 = np.percentile(X_train['C1'], 50)
c1_75 = np.percentile(X_train['C1'], 75)

# Subset 0: C1 < 25th percentile
X_train_0 = X_train[X_train['C1'] < c1_25]
y_train_0 = y_train[X_train['C1'] < c1_25]
X_test_0 = X_test[X_test['C1'] < c1_25]
y_test_0 = y_test[X_test['C1'] < c1_25]

# Subset 1: 25th percentile <= C1 < 50th percentile
X_train_1 = X_train[(X_train['C1'] >= c1_25) & (X_train['C1'] < c1_50)]
y_train_1 = y_train[(X_train['C1'] >= c1_25) & (X_train['C1'] < c1_50)]
X_test_2 = X_test[(X_test['C1'] >= c1_25) & (X_test['C1'] < c1_50)]
y_test_2 = y_test[(X_test['C1'] >= c1_25) & (X_test['C1'] < c1_50)]

# Subset 2: 50th percentile <= C1 < 75th percentile
X_train_2 = X_train[(X_train['C1'] >= c1_50) & (X_train['C1'] < c1_75)]
y_train_2 = y_train[(X_train['C1'] >= c1_50) & (X_train['C1'] < c1_75)]
X_test_2 = X_test[(X_test['C1'] >= c1_50) & (X_test['C1'] < c1_75)]
y_test_2 = y_test[(X_test['C1'] >= c1_50) & (X_test['C1'] < c1_75)]

# Subset 3: C1 >= 75th percentile
X_train_3 = X_train[X_train['C1'] >= c1_75]
y_train_3 = y_train[X_train['C1'] >= c1_75]
X_test_3 = X_test[X_test['C1'] >= c1_75]
y_test_3 = y_test[X_test['C1'] >= c1_75]

# %%
# X_train.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 3212 entries, 3612 to 3174
# Data columns (total 40 columns):

# scaled_data_df.info()
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4016 entries, 0 to 4015
# Data columns (total 40 columns):

# X_train_0.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 24 entries, 2791 to 1076
# Data columns (total 40 columns):

# X_train_1.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 1478 entries, 3612 to 860
# Data columns (total 40 columns):

# X_train_2.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 850 entries, 3838 to 3507
# Data columns (total 40 columns):

# X_train_3.info()
# <class 'pandas.core.frame.DataFrame'>
# Index: 860 entries, 3248 to 3174
# Data columns (total 40 columns):
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3212 entries, 3612 to 3174
# Data columns (total 40 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   C20     3212 non-null   float64
#  1   C3      3212 non-null   float64
#  2   C4      3212 non-null   float64
#  3   C1      3212 non-null   float64
#  4   C5      3212 non-null   float64
#  5   C6      3212 non-null   float64
#  6   C2      3212 non-null   float64
#  7   C21     3212 non-null   float64
#  8   C18     3212 non-null   float64
#  9   C8      3212 non-null   float64
#  10  C9      3212 non-null   float64
#  11  C10     3212 non-null   float64
#  12  C17     3212 non-null   float64
#  13  C19     3212 non-null   float64
#  14  C7      3212 non-null   float64
#  15  C11     3212 non-null   float64
#  16  C12     3212 non-null   float64
#  17  C13     3212 non-null   float64
#  18  C14     3212 non-null   float64
#  19  C15     3212 non-null   float64
# ...

# %%
from sklearn.ensemble import BaggingClassifier, GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

# Model 0: Random Forest for Subset 0
bagging_classifier0 = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
bagging_classifier0.fit(X_train_0, y_train_0)


# Model 1: Random Forest for Subset 1
rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(X_train_1, y_train_1)
# bagging_classifier1 = BaggingClassifier(base_estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
# bagging_classifier1.fit(X_train_1, y_train_1)


# Model 2: Gradient Boosting for Subset 2
# gb_classifier = GradientBoostingClassifier(n_estimators=100, random_state=42)
# gb_classifier.fit(X_train_2, y_train_2)
gb_classifier = GradientBoostingClassifier(loss='deviance', n_estimators=100, random_state=42)
gb_classifier.fit(X_train_2, y_train_2)


# Model 3: SVM for Subset 3
# svm_classifier = SVC(kernel='linear', probability=True, random_state=42)
# svm_classifier.fit(X_train_3, y_train_3)
dt_classifier = DecisionTreeClassifier(max_depth=5, random_state=42)
dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=5, random_state=42)

# %%
# # Subset 0: C1 < 25th percentile
# X_test_0 = X_test[X_test['C1'] < c1_25]
# y_test_0 = y_test[X_test['C1'] < c1_25]
# y_pred_0 = bagging_classifier0.predict_proba(X_test_0)[:, 1]

# # Subset 0: 25th percentile <= C1 < 50th percentile
# X_test_1 = X_test[(X_test['C1'] >= c1_25) & (X_test['C1'] < c1_50)]
# y_test_1 = y_test[(X_test['C1'] >= c1_25) & (X_test['C1'] < c1_50)]
# y_pred_1 = bagging_classifier1.predict_proba(X_test_1)[:, 1]

# # Subset 2: 50th percentile <= C1 < 75th percentile
# X_test_2 = X_test[(X_test['C1'] >= c1_50) & (X_test['C1'] < c1_75)]
# y_test_2 = y_test[(X_test['C1'] >= c1_50) & (X_test['C1'] < c1_75)]
# y_pred_2 = gb_classifier.predict_proba(X_test_2)[:, 1]

# # Subset 3: C1 >= 75th percentile
# X_test_3 = X_test[X_test['C1'] >= c1_75]
# y_test_3 = y_test[X_test['C1'] >= c1_75]
# y_pred_3 = dt_classifier.predict_proba(X_test_3)[:, 1]


y_pred_0 = bagging_classifier0.predict_proba(X_test_0)[:, 1]
y_pred_1 = bagging_classifier1.predict_proba(X_test_1)[:, 1]
y_pred_2 = gb_classifier.predict_proba(X_test_2)[:, 1]
y_pred_3 = dt_classifier.predict_proba(X_test_3)[:, 1]

# %%
# Combine probabilities into a single array
combined_probs = np.zeros(len(X_test))
combined_probs[X_test['C1'] < c1_25] = y_pred_0
combined_probs[(X_test['C1'] >= c1_25) & (X_test['C1'] < c1_50)] = y_pred_1
combined_probs[(X_test['C1'] >= c1_50) & (X_test['C1'] < c1_75)] = y_pred_2
combined_probs[X_test['C1'] >= c1_75] = y_pred_3

from sklearn.metrics import roc_curve

# Compute ROC curve
fpr, tpr, thresholds = roc_curve(y_test, combined_probs)

# Compute Youden's Index
youden_index = tpr - fpr
optimal_threshold_index = youden_index.argmax()
optimal_threshold = thresholds[optimal_threshold_index]

print("Optimal Threshold (Youden's Index):", optimal_threshold)


# Convert probabilities to binary predictions
final_preds = (combined_probs >= optimal_threshold).astype(int)

# Evaluate the final model
from sklearn.metrics import accuracy_score, classification_report, roc_auc_score, confusion_matrix

accuracy = accuracy_score(y_test, final_preds)
print("Accuracy:", accuracy)

print("\nClassification Report:")
print(classification_report(y_test, final_preds))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, final_preds))

auc = roc_auc_score(y_test, combined_probs)
print("\nAUC:", auc)


# Accuracy: 0.7711442786069652

# Classification Report:
#               precision    recall  f1-score   support

#            0       0.80      0.82      0.81       487
#            1       0.72      0.69      0.70       317

#     accuracy                           0.77       804
#    macro avg       0.76      0.76      0.76       804
# weighted avg       0.77      0.77      0.77       804


# Confusion Matrix:
# [[401  86]
#  [ 98 219]]

# AUC: 0.8539665368994489
# Out:
# Optimal Threshold (Youden's Index): 0.3716666666666667
# Accuracy: 0.7587064676616916
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.71      0.78       487
#            1       0.65      0.83      0.73       317
#
#     accuracy                           0.76       804
#    macro avg       0.76      0.77      0.76       804
# weighted avg       0.78      0.76      0.76       804
#
#
# Confusion Matrix:
# [[347 140]
#  [ 54 263]]
#
# AUC: 0.8539665368994489

# %% [markdown]
# # Train 2 models based on LOC

# %%
# Import train_test_split library
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and testing sets (20%)
X_train, X_test, y_train, y_test = train_test_split(feature_X, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Fit scaler on training data only
scaler_standard = StandardScaler()
X_train_scaled = scaler_standard.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler_standard.transform(X_test)

# %%
import numpy as np
import pandas as pd

# Calculate percentiles
c1_50 = np.percentile(X_train['C1'], 50)

# Subset 1: small: C1 < 50th percentile
X_train_s = X_train_scaled[X_train['C1'] < c1_50]
y_train_s = y_train[X_train['C1'] < c1_50]
X_test_s = X_test_scaled[X_test['C1'] < c1_50]
y_test_s = y_test[X_test['C1'] < c1_50]

# Subset 2: large: C1 >= 50th percentile
X_train_l = X_train_scaled[X_train['C1'] >= c1_50]
y_train_l = y_train[X_train['C1'] >= c1_50]
X_test_l = X_test_scaled[X_test['C1'] >= c1_50]
y_test_l = y_test[X_test['C1'] >= c1_50]

# %%
print(len(X_train_s), len(X_train_l))
# 1502 1710

print(len(X_test_s), len(X_test_l))
# 379 425
# Out:
# 1502 1710
# 379 425

# %%
# Import required libraries
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
# Models for small group
models_small = {
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),
    "MLP": MLPClassifier(hidden_layer_sizes=(128, 64), max_iter=500, random_state=42),
    "GradientBoosting": GradientBoostingClassifier(n_estimators=100, random_state=42)
}

# Train and predict probabilities for small group
print("Results for SMALL group:")
probabilities_s = []
for name, model in models_small.items():
    print(f"Training {name}...")
    model.fit(X_train_s, y_train_s)
    y_pred_proba = model.predict_proba(X_test_s)[:, 1]  # Get probabilities
    probabilities_s.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_s, model.predict(X_test_s)):.4f}")

# Average probabilities for small group
avg_proba_s = np.mean(probabilities_s, axis=0)

# Scaler before split
# Results for SMALL group:
# Training RandomForest...
# Accuracy (RandomForest): 0.8206
# Training MLP...
# Accuracy (MLP): 0.8021
# Training GradientBoosting...
# Accuracy (GradientBoosting): 0.7757
# Out:
# Results for SMALL group:
# Training RandomForest...
# Accuracy (RandomForest): 0.8206
# Training MLP...
# Accuracy (MLP): 0.7995
# Training GradientBoosting...
# Accuracy (GradientBoosting): 0.7757

# %%
# Models for large group
models_large = {
    "Bagging": BaggingClassifier(n_estimators=100, random_state=42),
    "KNeighbors": KNeighborsClassifier(n_neighbors=5),
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42)
}

# Train and predict probabilities for large group
print("\nResults for LARGE group:")
probabilities_l = []
for name, model in models_large.items():
    print(f"Training {name}...")
    model.fit(X_train_l, y_train_l)
    y_pred_proba = model.predict_proba(X_test_l)[:, 1]  # Get probabilities
    probabilities_l.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_l, model.predict(X_test_l)):.4f}")

# Average probabilities for large group
avg_proba_l = np.mean(probabilities_l, axis=0)

# Scaler before split
# Results for LARGE group:
# Training Bagging...
# Accuracy (Bagging): 0.7647
# Training KNeighbors...
# Accuracy (KNeighbors): 0.6729
# Training RandomForest...
# Accuracy (RandomForest): 0.7812
# Out:
# Results for LARGE group:
# Training Bagging...
# Accuracy (Bagging): 0.7647
# Training KNeighbors...
# Accuracy (KNeighbors): 0.6753
# Training RandomForest...
# Accuracy (RandomForest): 0.7788

# %%
# Combine probabilities and ground truths
final_proba = np.concatenate((avg_proba_s, avg_proba_l), axis=0)
final_y_test = np.concatenate((y_test_s, y_test_l), axis=0)
final_pred = (final_proba >= 0.5).astype(int)  # Apply threshold

# Evaluate combined results
print("\nFinal Combined Results:")
print(f"Accuracy: {accuracy_score(final_y_test, final_pred):.4f}")
print(f"Precision: {precision_score(final_y_test, final_pred):.4f}")
print(f"Recall: {recall_score(final_y_test, final_pred):.4f}")
print(f"F1-Score: {f1_score(final_y_test, final_pred):.4f}")

# Final Combined Results:
# Accuracy: 0.7736
# Precision: 0.7129
# Recall: 0.7129
# F1-Score: 0.7129
# Out:
# Final Combined Results:
# Accuracy: 0.7774
# Precision: 0.7184
# Recall: 0.7161
# F1-Score: 0.7172

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score, accuracy_score, precision_score,
    recall_score, f1_score, matthews_corrcoef
)

def get_optimal_threshold(y_true, y_proba):
    """
    Compute the optimal threshold using Youden's Index.
    """
    fpr, tpr, thresholds = roc_curve(y_true, y_proba)
    youden_index = tpr - fpr
    optimal_idx = np.argmax(youden_index)
    optimal_threshold = thresholds[optimal_idx]
    return optimal_threshold

# Combine probabilities and ground truths for evaluation
final_proba = np.concatenate((avg_proba_s, avg_proba_l), axis=0)
final_y_test = np.concatenate((y_test_s, y_test_l), axis=0)

# Get optimal threshold using Youden's Index
optimal_threshold = get_optimal_threshold(final_y_test, final_proba)
print(f"Optimal Threshold using Youden's Index: {optimal_threshold:.4f}")

# Apply the optimal threshold for predictions
final_pred = (final_proba >= optimal_threshold).astype(int)

# Evaluate combined results
print("\nFinal Combined Results (Using Optimal Threshold):")
print(f"Accuracy: {accuracy_score(final_y_test, final_pred):.4f}")
print(f"Precision: {precision_score(final_y_test, final_pred):.4f}")
print(f"Recall: {recall_score(final_y_test, final_pred):.4f}")
print(f"F1-Score: {f1_score(final_y_test, final_pred):.4f}")
print(f"MCC: {matthews_corrcoef(final_y_test, final_pred):.4f}")
print(f"AUC: {roc_auc_score(final_y_test, final_proba):.4f}")


# Optimal Threshold using Youden's Index: 0.3400

# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7649
# Precision: 0.6509
# Recall: 0.8707
# F1-Score: 0.7449
# MCC: 0.5548
# AUC: 0.8716
# Out:
# Optimal Threshold using Youden's Index: 0.3987
#
# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7774
# Precision: 0.6865
# Recall: 0.8013
# F1-Score: 0.7394
# MCC: 0.5521
# AUC: 0.8700

# %% [markdown]
# # Train 2 models based on LOC (Tensorflow)

# %%
# Import train_test_split library
from sklearn.model_selection import train_test_split

# Split the data into training (80%) and testing sets (20%)
X_train, X_test, y_train, y_test = train_test_split(feature_X, y, test_size=0.2, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler

# Fit scaler on training data only
scaler_standard = StandardScaler()
X_train_scaled = scaler_standard.fit_transform(X_train)

# Transform test data using the same scaler
X_test_scaled = scaler_standard.transform(X_test)

# %%
import numpy as np
import pandas as pd

# Calculate percentiles
c1_50 = np.percentile(X_train['C1'], 50)

# Subset 1: small: C1 < 50th percentile
X_train_s = X_train_scaled[X_train['C1'] < c1_50]
y_train_s = y_train[X_train['C1'] < c1_50]
X_test_s = X_test_scaled[X_test['C1'] < c1_50]
y_test_s = y_test[X_test['C1'] < c1_50]

# Subset 2: large: C1 >= 50th percentile
X_train_l = X_train_scaled[X_train['C1'] >= c1_50]
y_train_l = y_train[X_train['C1'] >= c1_50]
X_test_l = X_test_scaled[X_test['C1'] >= c1_50]
y_test_l = y_test[X_test['C1'] >= c1_50]

print(len(X_train_s), len(X_train_l))
# 1502 1710

print(len(X_test_s), len(X_test_l))
# 379 425
# Out:
# 1502 1710
# 379 425

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_decision_forests as tfdf
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score


# Build models for SMALL group

models_small = {
    "RandomForest": tfdf.keras.RandomForestModel(),
    "MLP": tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train_s.shape[1],)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')  # For binary classification
    ]),
    "GradientBoosting": tfdf.keras.GradientBoostedTreesModel()
}

probabilities_s = []
for name, model in models_small.items():
    if isinstance(model, tfdf.keras.RandomForestModel) or isinstance(model, tfdf.keras.GradientBoostedTreesModel):
        # Fit tree-based models
        model.fit(tfdf.keras.pd_dataframe_to_tf_dataset(pd.concat([X_train_s, y_train_s], axis=1), label="label"))
        y_pred_proba = model.predict(pd.concat([X_test_s], axis=1))[:, 1]
    else:
        # Compile and train MLP
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train_s, y_train_s, epochs=50, batch_size=32, verbose=0)
        y_pred_proba = model.predict(X_test_s).flatten()
    probabilities_s.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_s, (y_pred_proba > 0.5).astype(int)):.4f}")

# Average probabilities for small group
avg_proba_s = np.mean(probabilities_s, axis=0)

# Build models for LARGE group
print("\nResults for LARGE group:")
models_large = {
    "Bagging": tfdf.keras.RandomForestModel(),  # Bagging approximation
    "KNeighbors": tf.keras.Sequential([
        tf.keras.layers.Dense(128, activation='relu', input_shape=(X_train_l.shape[1],)),
        tf.keras.layers.Dropout(0.3),
        tf.keras.layers.Dense(64, activation='relu'),
        tf.keras.layers.Dense(1, activation='sigmoid')
    ]),
    "RandomForest": tfdf.keras.RandomForestModel()
}

probabilities_l = []
for name, model in models_large.items():
    print(f"Training {name}...")
    if isinstance(model, tfdf.keras.RandomForestModel):
        # Fit tree-based models
        model.fit(tfdf.keras.pd_dataframe_to_tf_dataset(pd.concat([X_train_l, y_train_l], axis=1), label="label"))
        y_pred_proba = model.predict(pd.concat([X_test_l], axis=1))[:, 1]
    else:
        # Compile and train MLP
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train_l, y_train_l, epochs=50, batch_size=32, verbose=0)
        y_pred_proba = model.predict(X_test_l).flatten()
    probabilities_l.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_l, (y_pred_proba > 0.5).astype(int)):.4f}")

# Average probabilities for large group
avg_proba_l = np.mean(probabilities_l, axis=0)

# Combine probabilities and ground truths
final_proba = np.concatenate((avg_proba_s, avg_proba_l), axis=0)
final_y_test = np.concatenate((y_test_s, y_test_l), axis=0)
final_pred = (final_proba >= 0.5).astype(int)

# Evaluate combined results
print("\nFinal Combined Results:")
print(f"Accuracy: {accuracy_score(final_y_test, final_pred):.4f}")
print(f"Precision: {precision_score(final_y_test, final_pred):.4f}")
print(f"Recall: {recall_score(final_y_test, final_pred):.4f}")
print(f"F1-Score: {f1_score(final_y_test, final_pred):.4f}")
# Out:
# WARNING:tensorflow:From C:\Users\LENOVO\AppData\Roaming\Python\Python310\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 4
#       2 import pandas as pd
#       3 import tensorflow as tf
# ----> 4 import tensorflow_decision_forests as tfdf
#       5 from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
#       8 # Build models for SMALL group
#
# ModuleNotFoundError: No module named 'tensorflow_decision_forests'

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier, BaggingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout


# Build models for SMALL group
models_small = {
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),
    "GradientBoosting": GradientBoostingClassifier(n_estimators=100, random_state=42),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train_s.shape[1],)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}

probabilities_s = []
for name, model in models_small.items():
    print(f"Training {name}...")
    if name == "MLP":
        # Compile and train MLP
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train_s, y_train_s, epochs=50, batch_size=32, verbose=0)
        y_pred_proba = model.predict(X_test_s).flatten()
    else:
        # Train traditional ML models
        model.fit(X_train_s, y_train_s)
        y_pred_proba = model.predict_proba(X_test_s)[:, 1]
    probabilities_s.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_s, (y_pred_proba > 0.5).astype(int)):.4f}")

# Average probabilities for small group
avg_proba_s = np.mean(probabilities_s, axis=0)

# Build models for LARGE group
print("\nResults for LARGE group:")
models_large = {
    "RandomForest": RandomForestClassifier(n_estimators=100, random_state=42),
    "Bagging": BaggingClassifier(n_estimators=100, random_state=42),
    "MLP": Sequential([
        Dense(128, activation='relu', input_shape=(X_train_l.shape[1],)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')
    ])
}

probabilities_l = []
for name, model in models_large.items():
    print(f"Training {name}...")
    if name == "MLP":
        # Compile and train MLP
        model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
        model.fit(X_train_l, y_train_l, epochs=50, batch_size=32, verbose=0)
        y_pred_proba = model.predict(X_test_l).flatten()
    else:
        # Train traditional ML models
        model.fit(X_train_l, y_train_l)
        y_pred_proba = model.predict_proba(X_test_l)[:, 1]
    probabilities_l.append(y_pred_proba)
    print(f"Accuracy ({name}): {accuracy_score(y_test_l, (y_pred_proba > 0.5).astype(int)):.4f}")

# Average probabilities for large group
avg_proba_l = np.mean(probabilities_l, axis=0)

# Combine probabilities and ground truths
final_proba = np.concatenate((avg_proba_s, avg_proba_l), axis=0)
final_y_test = np.concatenate((y_test_s, y_test_l), axis=0)
final_pred = (final_proba >= 0.5).astype(int)

# Evaluate combined results
print("\nFinal Combined Results:")
print(f"Accuracy: {accuracy_score(final_y_test, final_pred):.4f}")
print(f"Precision: {precision_score(final_y_test, final_pred):.4f}")
print(f"Recall: {recall_score(final_y_test, final_pred):.4f}")
print(f"F1-Score: {f1_score(final_y_test, final_pred):.4f}")
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Training RandomForest...
# Accuracy (RandomForest): 0.8206
# Training GradientBoosting...
# Accuracy (GradientBoosting): 0.7757
# Training MLP...
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy (MLP): 0.7678
#
# Results for LARGE group:
# Training RandomForest...
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Accuracy (RandomForest): 0.7788
# ...

# %%
from sklearn.metrics import (
    roc_curve, roc_auc_score, accuracy_score, precision_score,
    recall_score, f1_score, matthews_corrcoef
)

def get_optimal_threshold(y_true, y_proba):
    """
    Compute the optimal threshold using Youden's Index.
    """
    fpr, tpr, thresholds = roc_curve(y_true, y_proba)
    youden_index = tpr - fpr
    optimal_idx = np.argmax(youden_index)
    optimal_threshold = thresholds[optimal_idx]
    return optimal_threshold

# Combine probabilities and ground truths for evaluation
final_proba = np.concatenate((avg_proba_s, avg_proba_l), axis=0)
final_y_test = np.concatenate((y_test_s, y_test_l), axis=0)

# Get optimal threshold using Youden's Index
optimal_threshold = get_optimal_threshold(final_y_test, final_proba)
print(f"Optimal Threshold using Youden's Index: {optimal_threshold:.4f}")

# Apply the optimal threshold for predictions
final_pred = (final_proba >= optimal_threshold).astype(int)

# Evaluate combined results
print("\nFinal Combined Results (Using Optimal Threshold):")
print(f"Accuracy: {accuracy_score(final_y_test, final_pred):.4f}")
print(f"Precision: {precision_score(final_y_test, final_pred):.4f}")
print(f"Recall: {recall_score(final_y_test, final_pred):.4f}")
print(f"F1-Score: {f1_score(final_y_test, final_pred):.4f}")
print(f"MCC: {matthews_corrcoef(final_y_test, final_pred):.4f}")
print(f"AUC: {roc_auc_score(final_y_test, final_proba):.4f}")


# Optimal Threshold using Youden's Index: 0.3987

# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7774
# Precision: 0.6865
# Recall: 0.8013
# F1-Score: 0.7394
# MCC: 0.5521
# AUC: 0.8700
# Out:
# Optimal Threshold using Youden's Index: 0.4081
#
# Final Combined Results (Using Optimal Threshold):
# Accuracy: 0.7836
# Precision: 0.6857
# Recall: 0.8328
# F1-Score: 0.7521
# MCC: 0.5716
# AUC: 0.8689

# %% [markdown]
# # test classification algorithms

# %%
from sklearn.model_selection import cross_val_score, cross_validate
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score, accuracy_score
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import (
    make_scorer, precision_score, recall_score, f1_score, 
    matthews_corrcoef, roc_auc_score
)

X_train = X_train_s
y_train = y_train_s
X_test = X_test_s
y_test = y_test_s

rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
# rf_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_rf = rf_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_rf)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_rf))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_rf))




# Define custom scorers for cross-validation
scoring = {
    'accuracy': 'accuracy',
    'precision': make_scorer(precision_score, average='binary'),  # For binary classification
    'recall': make_scorer(recall_score, average='binary'),
    'f1': make_scorer(f1_score, average='binary'),
    'mcc': make_scorer(matthews_corrcoef),
    'auc': make_scorer(roc_auc_score) # , needs_proba=True
}

# Perform cross-validation
cv_results = cross_validate(rf_classifier, X_train, y_train, cv=10, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")

# Train the model on the full training data for feature importances
# rf_classifier.fit(X_train, y_train)



# feature_importance = rf_classifier.feature_importances_
# plt.barh(X_train.columns, feature_importance)
# plt.show()
# Out:
# Cross-Validation Results:
# Accuracy: 0.7665 ± 0.0201
# Precision: 0.7285 ± 0.0243
# Recall: 0.7168 ± 0.0269
# F1-Score: 0.7225 ± 0.0249
# MCC: 0.5211 ± 0.0417
# AUC: 0.7600 ± 0.0209

# %%
from sklearn.ensemble import AdaBoostClassifier

# X_train = X_train_s
# y_train = y_train_s
# X_test = X_test_s
# y_test = y_test_s

# Initialize and train the AdaBoost classifier
ada_classifier = AdaBoostClassifier(n_estimators=50, random_state=42)
# ada_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_ada = ada_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_ada)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_ada))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_ada))


# Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(ada_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7273 ± 0.0216
# Precision: 0.7141 ± 0.0342
# Recall: 0.5972 ± 0.0281
# F1-Score: 0.6501 ± 0.0271
# MCC: 0.4345 ± 0.0457
# AUC: 0.8131 ± 0.0202

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# X_train = X_train_s
# y_train = y_train_s
# X_test = X_test_s
# y_test = y_test_s

# Initialize and train the Bagging classifier
bagging_classifier = BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=50, random_state=42)
# bagging_classifier.fit(X_train, y_train)

# Predictions
# y_pred_bagging = bagging_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_bagging)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_bagging))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_bagging))


# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(bagging_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7581 ± 0.0132
# Precision: 0.7255 ± 0.0107
# Recall: 0.6911 ± 0.0308
# F1-Score: 0.7077 ± 0.0204
# MCC: 0.5022 ± 0.0288
# AUC: 0.8543 ± 0.0136

# %%
from sklearn.neighbors import KNeighborsClassifier

# X_train = X_train_s
# y_train = y_train_s
# X_test = X_test_s
# y_test = y_test_s

# Initialize and train the k-Nearest Neighbors classifier
knn_classifier = KNeighborsClassifier(n_neighbors=5)
# knn_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_knn = knn_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_knn)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_knn))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_knn))

# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(knn_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7291 ± 0.0139
# Precision: 0.6838 ± 0.0165
# Recall: 0.6728 ± 0.0197
# F1-Score: 0.6782 ± 0.0175
# MCC: 0.4445 ± 0.0288
# AUC: 0.7958 ± 0.0129

# %%
from sklearn.neural_network import MLPClassifier

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train the MLP classifier
mlp_classifier = MLPClassifier(hidden_layer_sizes=(100,), max_iter=300, random_state=42)
# mlp_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_mlp = mlp_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_mlp)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_mlp))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_mlp))


# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(mlp_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\LENOVO\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:690: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (300) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Cross-Validation Results:
# ...

# %%
from sklearn.naive_bayes import GaussianNB

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train the Naive Bayes classifier
nb_classifier = GaussianNB()
# nb_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_nb = nb_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_nb)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_nb))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_nb))


# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(nb_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7077 ± 0.0123
# Precision: 0.6625 ± 0.0209
# Recall: 0.6361 ± 0.0092
# F1-Score: 0.6488 ± 0.0101
# MCC: 0.3991 ± 0.0234
# AUC: 0.7747 ± 0.0136

# %%
from sklearn.ensemble import GradientBoostingClassifier

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train the Gradient Boosting classifier
# logitboost_classifier = GradientBoostingClassifier(loss='deviance', n_estimators=100, random_state=42)
logitboost_classifier = GradientBoostingClassifier(loss='exponential', n_estimators=100, random_state=42)
# logitboost_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_logitboost = logitboost_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_logitboost)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_logitboost))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_logitboost))



# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(logitboost_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7441 ± 0.0235
# Precision: 0.7356 ± 0.0377
# Recall: 0.6214 ± 0.0283
# F1-Score: 0.6733 ± 0.0287
# MCC: 0.4702 ± 0.0495
# AUC: 0.8275 ± 0.0183

# %%
from sklearn.tree import DecisionTreeClassifier

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train a Decision Tree classifier
part_equiv_classifier = DecisionTreeClassifier(max_depth=5, random_state=42)
# part_equiv_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_part = part_equiv_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_part)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_part))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_part))


# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(part_equiv_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7441 ± 0.0236
# Precision: 0.7595 ± 0.0399
# Recall: 0.5848 ± 0.0679
# F1-Score: 0.6578 ± 0.0453
# MCC: 0.4716 ± 0.0506
# AUC: 0.8128 ± 0.0218

# %%
from sklearn.tree import DecisionTreeClassifier

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train a Decision Tree classifier (J48 equivalent)
j48_classifier = DecisionTreeClassifier(criterion='gini', max_depth=None, random_state=42)
# j48_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_j48 = j48_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_j48)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_j48))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_j48))



# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(j48_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.7186 ± 0.0154
# Precision: 0.6737 ± 0.0156
# Recall: 0.6522 ± 0.0301
# F1-Score: 0.6627 ± 0.0223
# MCC: 0.4216 ± 0.0332
# AUC: 0.7127 ± 0.0183

# %%
from sklearn.tree import DecisionTreeClassifier

# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# Initialize and train a Decision Stump (a decision tree with max depth = 1)
stump_classifier = DecisionTreeClassifier(max_depth=1, random_state=42)
# stump_classifier.fit(X_train, y_train)

# # Predictions
# y_pred_stump = stump_classifier.predict(X_test)

# accuracy = accuracy_score(y_test, y_pred_stump)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_stump))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_stump))



# # Define custom scorers for cross-validation
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),  # For binary classification
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results = cross_validate(stump_classifier, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# Cross-Validation Results:
# Accuracy: 0.6964 ± 0.0296
# Precision: 0.6957 ± 0.0973
# Recall: 0.6243 ± 0.2124
# F1-Score: 0.6231 ± 0.0533
# MCC: 0.4168 ± 0.0203
# AUC: 0.6869 ± 0.0097

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
# from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score
from scikeras.wrappers import KerasClassifier

# Assign appropriate datasets
# X_train = X_train_l
# y_train = y_train_l
# X_test = X_test_l
# y_test = y_test_l

# # Build the MLP model
# mlp_model = Sequential([
#     Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
#     Dropout(0.3),
#     Dense(64, activation='relu'),
#     Dense(1, activation='sigmoid')  # Use 'softmax' for multi-class
# ])

# # Compile the model
# mlp_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# # Train the model
# history = mlp_model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=32)

# # Predictions
# y_pred_mlp_prob = mlp_model.predict(X_test)



# # Using ROC Curve to Maximize the Youden's Index
# from sklearn.metrics import roc_curve

# # Compute ROC curve
# fpr, tpr, thresholds = roc_curve(y_test, y_pred_mlp_prob)

# # Compute Youden's Index
# youden_index = tpr - fpr
# optimal_threshold_index = youden_index.argmax()
# optimal_threshold = thresholds[optimal_threshold_index]

# print("Optimal Threshold (Youden's Index):", optimal_threshold)


# # Using Precision-Recall Curve to Maximize F1-Score
# from sklearn.metrics import precision_recall_curve

# # Compute Precision-Recall curve
# precision, recall, thresholds = precision_recall_curve(y_test, y_pred_mlp_prob)

# # Compute F1-score for each threshold
# f1_scores = 2 * (precision * recall) / (precision + recall)
# optimal_threshold_index = f1_scores.argmax()
# optimal_threshold = thresholds[optimal_threshold_index]

# print("Optimal Threshold (Max F1-Score):", optimal_threshold)




# # Convert probabilities to binary predictions
# y_pred_mlp = (y_pred_mlp_prob >= optimal_threshold).astype(int).flatten()  

# # Evaluate the model
# accuracy = accuracy_score(y_test, y_pred_mlp)
# print("Accuracy:", accuracy)

# print("\nClassification Report:")
# print(classification_report(y_test, y_pred_mlp))

# print("\nConfusion Matrix:")
# print(confusion_matrix(y_test, y_pred_mlp))



def create_mlp_model():
    model = Sequential([
        Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
        Dropout(0.3),
        Dense(64, activation='relu'),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model



# Wrap the model using KerasClassifier
mlp_model_wrapper = KerasClassifier(
    model=create_mlp_model,
    epochs=50,
    batch_size=32,
    verbose=0
)


# Wrap the model using KerasClassifier
# mlp_model_wrapper = KerasClassifier(build_fn=create_mlp_model, epochs=50, batch_size=32, verbose=0)

scoring = {
    'accuracy': 'accuracy',
    'precision': make_scorer(precision_score),
    'recall': make_scorer(recall_score),
    'f1': make_scorer(f1_score),
    'mcc': make_scorer(matthews_corrcoef),
    'auc': make_scorer(roc_auc_score, needs_proba=True)  # Needs predicted probabilities
}
cv_results = cross_validate(mlp_model_wrapper, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("Cross-Validation Results:")
print(f"Accuracy: {cv_results['test_accuracy'].mean():.4f} ± {cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results['test_precision'].mean():.4f} ± {cv_results['test_precision'].std():.4f}")
print(f"Recall: {cv_results['test_recall'].mean():.4f} ± {cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results['test_f1'].mean():.4f} ± {cv_results['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
# ...

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, MaxPooling1D, Reshape

# Assign appropriate datasets
# X_train = X_train_s
# y_train = y_train_s
# X_test = X_test_s
# y_test = y_test_s

# Define a CNN model for tabular data
def create_cnn_model():
    model = Sequential([
        Reshape((X_train.shape[1], 1), input_shape=(X_train.shape[1],)),  # Reshape to 1D
        Conv1D(64, kernel_size=2, activation='relu'),
        MaxPooling1D(pool_size=2),
        Conv1D(32, kernel_size=2, activation='relu'),
        Flatten(),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap the model
cnn_model_wrapper = KerasClassifier(model=create_cnn_model, epochs=50, batch_size=32, verbose=0)

# Perform cross-validation
cv_results_cnn = cross_validate(cnn_model_wrapper, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("CNN Cross-Validation Results:")
print(f"Accuracy: {cv_results_cnn['test_accuracy'].mean():.4f} ± {cv_results_cnn['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results_cnn['test_precision'].mean():.4f} ± {cv_results_cnn['test_precision'].std():.4f}")
print(f"Recall: {cv_results_cnn['test_recall'].mean():.4f} ± {cv_results_cnn['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results_cnn['test_f1'].mean():.4f} ± {cv_results_cnn['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\reshaping\reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\reshaping\reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\reshaping\reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ...

# %%
print(X_train.shape, X_test.shape)
# (3212, 40) (804, 40)
# Out:
# (1710, 40) (425, 40)

# %%
from tensorflow.keras.layers import LSTM, GRU
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense, Dropout
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_validate
from sklearn.metrics import make_scorer, precision_score, recall_score, f1_score
from scikeras.wrappers import KerasClassifier
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Flatten, Dense, Dropout, MaxPooling1D, Reshape

# Assign appropriate datasets
# X_train = X_train_s
# y_train = y_train_s
# X_test = X_test_s
# y_test = y_test_s

# Define an RNN model for tabular data
def create_rnn_model():
    model = Sequential([
        Reshape((X_train.shape[1], 1), input_shape=(X_train.shape[1],)),
        LSTM(64, activation='relu', return_sequences=True),
        LSTM(32, activation='relu'),
        Dense(64, activation='relu'),
        Dropout(0.3),
        Dense(1, activation='sigmoid')  # For binary classification
    ])
    model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    return model

# Wrap the model
rnn_model_wrapper = KerasClassifier(build_fn=create_rnn_model, epochs=50, batch_size=32, verbose=0)

# # Define custom scorers
# scoring = {
#     'accuracy': 'accuracy',
#     'precision': make_scorer(precision_score, average='binary'),
#     'recall': make_scorer(recall_score, average='binary'),
#     'f1': make_scorer(f1_score, average='binary')
# }

# Perform cross-validation
cv_results_rnn = cross_validate(rnn_model_wrapper, X_train, y_train, cv=5, scoring=scoring)

# Extract metrics
print("RNN Cross-Validation Results:")
print(f"Accuracy: {cv_results_rnn['test_accuracy'].mean():.4f} ± {cv_results_rnn['test_accuracy'].std():.4f}")
print(f"Precision: {cv_results_rnn['test_precision'].mean():.4f} ± {cv_results_rnn['test_precision'].std():.4f}")
print(f"Recall: {cv_results_rnn['test_recall'].mean():.4f} ± {cv_results_rnn['test_recall'].std():.4f}")
print(f"F1-Score: {cv_results_rnn['test_f1'].mean():.4f} ± {cv_results_rnn['test_f1'].std():.4f}")
print(f"MCC: {cv_results['test_mcc'].mean():.4f} ± {cv_results['test_mcc'].std():.4f}")
print(f"AUC: {cv_results['test_auc'].mean():.4f} ± {cv_results['test_auc'].std():.4f}")
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# C:\Users\LENOVO\anaconda3\lib\site-packages\keras\src\layers\reshaping\reshape.py:39: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Users\LENOVO\anaconda3\lib\site-packages\scikeras\wrappers.py:925: UserWarning: ``build_fn`` will be renamed to ``model`` in a future release, at which point use of ``build_fn`` will raise an Error instead.
#   X, y = self._initialize(X, y)
# ...

# %%
# !pip install xgboost
# !pip install lightgbm
# Out:
# ...
#      -------------------------------------- 124.9/124.9 MB 1.4 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# ...
#      ---------------------------------------- 1.4/1.4 MB 1.1 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\lenovo\anaconda3\lib\site-packages)
# ...

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import cross_validate

# Define the XGBoost classifier
xgb_model = XGBClassifier(
    objective='binary:logistic',  # Binary classification
    eval_metric='logloss',       # Loss metric for evaluation
#     use_label_encoder=False,     # Disable encoding of labels
    n_estimators=100,            # Number of trees
    max_depth=6,                 # Maximum tree depth
    learning_rate=0.1,           # Learning rate
    random_state=42              # For reproducibility
)

# # Perform 10-fold cross-validation on the small group
# xgb_cv_results_s = cross_validate(xgb_model, X_train_s, y_train_s, cv=10, scoring=['accuracy', 'precision', 'recall', 'f1'])

# # Perform 10-fold cross-validation on the large group
# xgb_cv_results_l = cross_validate(xgb_model, X_train_l, y_train_l, cv=10, scoring=['accuracy', 'precision', 'recall', 'f1'])

# # Print results for XGBoost
# print("\nXGBoost Results (Small Group):")
# print(f"Accuracy: {xgb_cv_results_s['test_accuracy'].mean():.4f} ± {xgb_cv_results_s['test_accuracy'].std():.4f}")
# print(f"Precision: {xgb_cv_results_s['test_precision'].mean():.4f} ± {xgb_cv_results_s['test_precision'].std():.4f}")
# print(f"Recall: {xgb_cv_results_s['test_recall'].mean():.4f} ± {xgb_cv_results_s['test_recall'].std():.4f}")
# print(f"F1-Score: {xgb_cv_results_s['test_f1'].mean():.4f} ± {xgb_cv_results_s['test_f1'].std():.4f}")

# print("\nXGBoost Results (Large Group):")
# print(f"Accuracy: {xgb_cv_results_l['test_accuracy'].mean():.4f} ± {xgb_cv_results_l['test_accuracy'].std():.4f}")
# print(f"Precision: {xgb_cv_results_l['test_precision'].mean():.4f} ± {xgb_cv_results_l['test_precision'].std():.4f}")
# print(f"Recall: {xgb_cv_results_l['test_recall'].mean():.4f} ± {xgb_cv_results_l['test_recall'].std():.4f}")
# print(f"F1-Score: {xgb_cv_results_l['test_f1'].mean():.4f} ± {xgb_cv_results_l['test_f1'].std():.4f}")


# Perform 10-fold cross-validation on the large group
xgb_cv_results = cross_validate(xgb_model, X_train, y_train, cv=5, scoring=scoring)

# Print results for XGBoost
print("\nXGBoost Results:")
print(f"Accuracy: {xgb_cv_results['test_accuracy'].mean():.4f} ± {xgb_cv_results['test_accuracy'].std():.4f}")
print(f"Precision: {xgb_cv_results['test_precision'].mean():.4f} ± {xgb_cv_results['test_precision'].std():.4f}")
print(f"Recall: {xgb_cv_results['test_recall'].mean():.4f} ± {xgb_cv_results['test_recall'].std():.4f}")
print(f"F1-Score: {xgb_cv_results['test_f1'].mean():.4f} ± {xgb_cv_results['test_f1'].std():.4f}")
print(f"MCC: {xgb_cv_results['test_mcc'].mean():.4f} ± {xgb_cv_results['test_mcc'].std():.4f}")
print(f"AUC: {xgb_cv_results['test_auc'].mean():.4f} ± {xgb_cv_results['test_auc'].std():.4f}")
# Out:
# XGBoost Results:
# Accuracy: 0.7469 ± 0.0234
# Precision: 0.7217 ± 0.0267
# Recall: 0.6559 ± 0.0353
# F1-Score: 0.6872 ± 0.0315
# MCC: 0.4770 ± 0.0492
# AUC: 0.8387 ± 0.0179
